# %% [markdown]
# <a href="https://colab.research.google.com/github/oneoclockc/MLclass/blob/main/w2_practice_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Pandas data structure

# %%
# !wget https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_02/data/earthquakes.csv
# !wget https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_02/data/example_data.csv
# !wget https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_02/data/parsed.csv
# !wget https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_02/data/quakes.db
# !wget https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_02/data/tsunamis.csv
# !mkdir data
# !mv *.csv data
# !mv *.db data
# Out:
# --2024-09-15 13:36:00--  https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_02/data/earthquakes.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3515656 (3.4M) [text/plain]
# Saving to: ‘earthquakes.csv’
#
# earthquakes.csv     100%[===================>]   3.35M  --.-KB/s    in 0.1s
#
# 2024-09-15 13:36:01 (29.6 MB/s) - ‘earthquakes.csv’ saved [3515656/3515656]
#
# --2024-09-15 13:36:01--  https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_02/data/example_data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# ...

# %%
import numpy as np

data = np.genfromtxt(
    'data/example_data.csv', delimiter=';',
    names=True, dtype=None, encoding='UTF'
)
data
# Out:
# array([('2018-10-13 11:10:23.560', '262km NW of Ozernovskiy, Russia', 'mww', 6.7, 'green', 1),
#        ('2018-10-13 04:34:15.580', '25km E of Bitung, Indonesia', 'mww', 5.2, 'green', 0),
#        ('2018-10-13 00:13:46.220', '42km WNW of Sola, Vanuatu', 'mww', 5.7, 'green', 0),
#        ('2018-10-12 21:09:49.240', '13km E of Nueva Concepcion, Guatemala', 'mww', 5.7, 'green', 0),
#        ('2018-10-12 02:52:03.620', '128km SE of Kimbe, Papua New Guinea', 'mww', 5.6, 'green', 1)],
#       dtype=[('time', '<U23'), ('place', '<U37'), ('magType', '<U3'), ('mag', '<f8'), ('alert', '<U5'), ('tsunami', '<i8')])

# %%
data.shape
# Out:
# (5,)

# %%
data.dtype
# Out:
# dtype([('time', '<U23'), ('place', '<U37'), ('magType', '<U3'), ('mag', '<f8'), ('alert', '<U5'), ('tsunami', '<i8')])

# %%
for row in data :
    print(row[3])
# Out:
# 6.7
# 5.2
# 5.7
# 5.7
# 5.6

# %%
[row[3] for row in data]
# Out:
# [6.7, 5.2, 5.7, 5.7, 5.6]

# %%
max([row[3] for row in data])
# Out:
# 6.7

# %%
for i, col in enumerate(data.dtype.names) :
  print(i,col)
# Out:
# 0 time
# 1 place
# 2 magType
# 3 mag
# 4 alert
# 5 tsunami

# %%
array_dict = {
    col: np.array([row[i] for row in data])
    for i, col in enumerate(data.dtype.names)
}
array_dict
# Out:
# {'time': array(['2018-10-13 11:10:23.560', '2018-10-13 04:34:15.580',
#         '2018-10-13 00:13:46.220', '2018-10-12 21:09:49.240',
#         '2018-10-12 02:52:03.620'], dtype='<U23'),
#  'place': array(['262km NW of Ozernovskiy, Russia', '25km E of Bitung, Indonesia',
#         '42km WNW of Sola, Vanuatu',
#         '13km E of Nueva Concepcion, Guatemala',
#         '128km SE of Kimbe, Papua New Guinea'], dtype='<U37'),
#  'magType': array(['mww', 'mww', 'mww', 'mww', 'mww'], dtype='<U3'),
#  'mag': array([6.7, 5.2, 5.7, 5.7, 5.6]),
#  'alert': array(['green', 'green', 'green', 'green', 'green'], dtype='<U5'),
#  'tsunami': array([1, 0, 0, 0, 1])}

# %%
i=0
np.array([row[i] for row in data])
# Out:
# array(['2018-10-13 11:10:23.560', '2018-10-13 04:34:15.580',
#        '2018-10-13 00:13:46.220', '2018-10-12 21:09:49.240',
#        '2018-10-12 02:52:03.620'], dtype='<U23')

# %%
# %%timeit
array_dict['mag'], max
# Out:
# 103 ns ± 0.956 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
import pandas as pd

place = pd.Series(array_dict['place'], name='place')
place
# Out:
# 0          262km NW of Ozernovskiy, Russia
# 1              25km E of Bitung, Indonesia
# 2                42km WNW of Sola, Vanuatu
# 3    13km E of Nueva Concepcion, Guatemala
# 4      128km SE of Kimbe, Papua New Guinea
# Name: place, dtype: object

# %%
place.name
# Out:
# 'place'

# %%
place.values
# Out:
# array(['262km NW of Ozernovskiy, Russia', '25km E of Bitung, Indonesia',
#        '42km WNW of Sola, Vanuatu',
#        '13km E of Nueva Concepcion, Guatemala',
#        '128km SE of Kimbe, Papua New Guinea'], dtype=object)

# %%
place_index = place.index
place_index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
place_index.values
# Out:
# array([0, 1, 2, 3, 4])

# %%
df = pd.DataFrame(array_dict)
df
# Out:
#                       time                                  place magType  \
# 0  2018-10-13 11:10:23.560        262km NW of Ozernovskiy, Russia     mww
# 1  2018-10-13 04:34:15.580            25km E of Bitung, Indonesia     mww
# 2  2018-10-13 00:13:46.220              42km WNW of Sola, Vanuatu     mww
# 3  2018-10-12 21:09:49.240  13km E of Nueva Concepcion, Guatemala     mww
# 4  2018-10-12 02:52:03.620    128km SE of Kimbe, Papua New Guinea     mww
#
#    mag  alert  tsunami
# 0  6.7  green        1
# 1  5.2  green        0
# 2  5.7  green        0
# 3  5.7  green        0
# 4  5.6  green        1

# %%
df['mag'].max
# Out:
# <bound method Series.max of 0    6.7
# 1    5.2
# 2    5.7
# 3    5.7
# 4    5.6
# Name: mag, dtype: float64>

# %%
df.dtypes
# Out:
# time        object
# place       object
# magType     object
# mag        float64
# alert       object
# tsunami      int64
# dtype: object

# %%
#task1
odd = [num for num in range(1,101) if num %2 !=0]

# %%
array_dict['mag']
# Out:
# array([6.7, 5.2, 5.7, 5.7, 5.6])

# %% [markdown]
# # Creating dataframe

# %%
import datetime as dt
import numpy as np
import pandas as pd

# %%
np.random.seed(0) # set seed so result is reproducible
pd.DataFrame(
    {
        'random': np.random.rand(5),
        'text': ['hot', 'warm', 'cool', 'cold', None],
        'truth': [np.random.choice([True, False]) for _ in range(5)]
    },
    index=pd.date_range(
        end=dt.date(2019, 4, 21),
        freq='1D',
        periods=5,
        name='date'
    )
)
# Out:
#               random  text  truth
# date
# 2019-04-17  0.548814   hot  False
# 2019-04-18  0.715189  warm   True
# 2019-04-19  0.602763  cool   True
# 2019-04-20  0.544883  cold  False
# 2019-04-21  0.423655  None   True

# %%
# !head -n 5 data/earthquakes.csv
# Out:
# alert,cdi,code,detail,dmin,felt,gap,ids,mag,magType,mmi,net,nst,place,rms,sig,sources,status,time,title,tsunami,type,types,tz,updated,url
# ,,37389218,https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci37389218&format=geojson,0.008693,,85.0,",ci37389218,",1.35,ml,,ci,26.0,"9km NE of Aguanga, CA",0.19,28,",ci,",automatic,1539475168010,"M 1.4 - 9km NE of Aguanga, CA",0,earthquake,",geoserve,nearby-cities,origin,phase-data,",-480.0,1539475395144,https://earthquake.usgs.gov/earthquakes/eventpage/ci37389218
# ,,37389202,https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci37389202&format=geojson,0.02003,,79.0,",ci37389202,",1.29,ml,,ci,20.0,"9km NE of Aguanga, CA",0.29,26,",ci,",automatic,1539475129610,"M 1.3 - 9km NE of Aguanga, CA",0,earthquake,",geoserve,nearby-cities,origin,phase-data,",-480.0,1539475253925,https://earthquake.usgs.gov/earthquakes/eventpage/ci37389202
# ...

# %%
# !tail -n 5 data/earthquakes.csv
# Out:
# ,,73086771,https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73086771&format=geojson,0.01806,,185.0,",nc73086771,",0.62,md,,nc,13.0,"9km ENE of Mammoth Lakes, CA",0.03,6,",nc,",reviewed,1537230228060,"M 0.6 - 9km ENE of Mammoth Lakes, CA",0,earthquake,",geoserve,nearby-cities,origin,phase-data,",-480.0,1537285598315,https://earthquake.usgs.gov/earthquakes/eventpage/nc73086771
# ,,38063967,https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38063967&format=geojson,0.03041,,50.0,",ci38063967,",1.0,ml,,ci,28.0,"3km W of Julian, CA",0.21,15,",ci,",reviewed,1537230135130,"M 1.0 - 3km W of Julian, CA",0,earthquake,",geoserve,nearby-cities,origin,phase-data,scitech-link,",-480.0,1537276800970,https://earthquake.usgs.gov/earthquakes/eventpage/ci38063967
# ...

# %%
#task1
df = pd.read_csv(
    'https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_02/data/earthquakes.csv'
)
df
# Out:
#      alert  cdi        code  \
# 0      NaN  NaN    37389218
# 1      NaN  NaN    37389202
# 2      NaN  4.4    37389194
# 3      NaN  NaN    37389186
# 4      NaN  NaN    73096941
# ...    ...  ...         ...
# 9327   NaN  NaN    73086771
# 9328   NaN  NaN    38063967
# 9329   NaN  NaN  2018261000
# 9330   NaN  NaN    38063959
# 9331   NaN  NaN    38063935
#
#                                                  detail      dmin  felt  \
# 0     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.008693   NaN
# 1     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.020030   NaN
# 2     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.021370  28.0
# 3     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.026180   NaN
# 4     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.077990   NaN
# ...                                                 ...       ...   ...
# 9327  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.018060   NaN
# ...

# %%
teammate = pd.DataFrame(
    np.array([
        ['이혜령', '아카이빙','경영'],
        ['문희경', '음악감상', '심리'],
        ['양이한', '영화감상', '응용통계'],
        ['정은유', '운동', '응용통계'],
        ['윤한세', '뜨개질', '응용통계']
    ]), columns=['name', 'hobby', 'major']
)
teammate
# Out:
#   name hobby major
# 0  이혜령  아카이빙    경영
# 1  문희경  음악감상    심리
# 2  양이한  영화감상  응용통계
# 3  정은유    운동  응용통계
# 4  윤한세   뜨개질  응용통계

# %%
teammate.to_csv('teammate.csv', index=False)

# %%
import pandas as pd

df = pd.read_csv('data/earthquakes.csv')

# %% [markdown]
# # Inspecting a DataFrame Object

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('data/earthquakes.csv')

# %%
df.head()
# Out:
#    cdi      code                                             detail      dmin  \
# 0  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.008693
# 1  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.020030
# 2  4.4  37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.021370
# 3  NaN  37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.026180
# 4  NaN  73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.077990
#
#    felt    gap           ids   mag magType  mmi  ... sources     status  \
# 0   NaN   85.0  ,ci37389218,  1.35      ml  NaN  ...    ,ci,  automatic
# 1   NaN   79.0  ,ci37389202,  1.29      ml  NaN  ...    ,ci,  automatic
# 2  28.0   21.0  ,ci37389194,  3.42      ml  NaN  ...    ,ci,  automatic
# 3   NaN   39.0  ,ci37389186,  0.44      ml  NaN  ...    ,ci,  automatic
# 4   NaN  192.0  ,nc73096941,  2.16      md  NaN  ...    ,nc,  automatic
#
# ...

# %% [markdown]
# # subsetting_data

# %%
df[['mag', 'title']]
# Out:
#        mag                                     title
# 0     1.35             M 1.4 - 9km NE of Aguanga, CA
# 1     1.29             M 1.3 - 9km NE of Aguanga, CA
# 2     3.42             M 3.4 - 8km NE of Aguanga, CA
# 3     0.44             M 0.4 - 9km NE of Aguanga, CA
# 4     2.16             M 2.2 - 10km NW of Avenal, CA
# ...    ...                                       ...
# 9327  0.62      M 0.6 - 9km ENE of Mammoth Lakes, CA
# 9328  1.00               M 1.0 - 3km W of Julian, CA
# 9329  2.40  M 2.4 - 35km NNE of Hatillo, Puerto Rico
# 9330  1.10             M 1.1 - 9km NE of Aguanga, CA
# 9331  0.66             M 0.7 - 9km NE of Aguanga, CA
#
# [9332 rows x 2 columns]

# %%
df[
    ['title', 'time']
    + [col for col in df.columns if col.startswith('mag')]
]
# Out:
#                                          title           time   mag magType
# 0                M 1.4 - 9km NE of Aguanga, CA  1539475168010  1.35      ml
# 1                M 1.3 - 9km NE of Aguanga, CA  1539475129610  1.29      ml
# 2                M 3.4 - 8km NE of Aguanga, CA  1539475062610  3.42      ml
# 3                M 0.4 - 9km NE of Aguanga, CA  1539474978070  0.44      ml
# 4                M 2.2 - 10km NW of Avenal, CA  1539474716050  2.16      md
# ...                                        ...            ...   ...     ...
# 9327      M 0.6 - 9km ENE of Mammoth Lakes, CA  1537230228060  0.62      md
# 9328               M 1.0 - 3km W of Julian, CA  1537230135130  1.00      ml
# 9329  M 2.4 - 35km NNE of Hatillo, Puerto Rico  1537229908180  2.40      md
# 9330             M 1.1 - 9km NE of Aguanga, CA  1537229545350  1.10      ml
# 9331             M 0.7 - 9km NE of Aguanga, CA  1537228864470  0.66      ml
#
# [9332 rows x 4 columns]

# %%
[col for col in df.columns if col.startswith('mag')]
# Out:
# ['mag', 'magType']

# %%
df[100:103]
# Out:
#     alert  cdi      code                                             detail  \
# 100   NaN  NaN  20280310  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 101   NaN  NaN  73096756  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 102   NaN  NaN  37388730  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#         dmin  felt    gap           ids   mag magType  ...  sources  \
# 100      NaN   NaN    NaN  ,ak20280310,  1.20      ml  ...     ,ak,
# 101  0.01355   NaN  185.0  ,nc73096756,  0.59      md  ...     ,nc,
# 102  0.02987   NaN   39.0  ,ci37388730,  1.33      ml  ...     ,ci,
#
#         status           time                                 title  tsunami  \
# 100  automatic  1539435449480      M 1.2 - 25km NW of Ester, Alaska        0
# 101  automatic  1539435391320  M 0.6 - 8km ESE of Mammoth Lakes, CA        0
# 102  automatic  1539435293090        M 1.3 - 8km ENE of Aguanga, CA        0
#
# ...

# %%
df[['title', 'time']][100:103]
# Out:
#                                     title           time
# 100      M 1.2 - 25km NW of Ester, Alaska  1539435449480
# 101  M 0.6 - 8km ESE of Mammoth Lakes, CA  1539435391320
# 102        M 1.3 - 8km ENE of Aguanga, CA  1539435293090

# %%
df[110:113]['title']
# Out:
# 110               M 1.1 - 35km S of Ester, Alaska
# 111    M 1.9 - 93km WNW of Arctic Village, Alaska
# 112      M 0.9 - 20km WSW of Smith Valley, Nevada
# Name: title, dtype: object

# %%
df.loc[:,'title']
# Out:
# 0                  M 1.4 - 9km NE of Aguanga, CA
# 1                  M 1.3 - 9km NE of Aguanga, CA
# 2                  M 3.4 - 8km NE of Aguanga, CA
# 3                  M 0.4 - 9km NE of Aguanga, CA
# 4                  M 2.2 - 10km NW of Avenal, CA
#                           ...
# 9327        M 0.6 - 9km ENE of Mammoth Lakes, CA
# 9328                 M 1.0 - 3km W of Julian, CA
# 9329    M 2.4 - 35km NNE of Hatillo, Puerto Rico
# 9330               M 1.1 - 9km NE of Aguanga, CA
# 9331               M 0.7 - 9km NE of Aguanga, CA
# Name: title, Length: 9332, dtype: object

# %%
df.loc[10:15, ['title', 'mag']]
# Out:
#                                                 title   mag
# 10                     M 0.5 - 10km NE of Aguanga, CA  0.50
# 11  M 2.8 - 53km SE of Punta Cana, Dominican Republic  2.77
# 12                      M 0.5 - 9km NE of Aguanga, CA  0.50
# 13         M 4.5 - 120km SSW of Banda Aceh, Indonesia  4.50
# 14                   M 2.1 - 14km NW of Parkfield, CA  2.13
# 15       M 2.0 - 156km WNW of Haines Junction, Canada  2.00

# %%
df.iloc[10:15, [19, 8]]
# Out:
#                                                 title   mag
# 10                     M 0.5 - 10km NE of Aguanga, CA  0.50
# 11  M 2.8 - 53km SE of Punta Cana, Dominican Republic  2.77
# 12                      M 0.5 - 9km NE of Aguanga, CA  0.50
# 13         M 4.5 - 120km SSW of Banda Aceh, Indonesia  4.50
# 14                   M 2.1 - 14km NW of Parkfield, CA  2.13

# %%
df.mag > 2
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 9327    False
# 9328    False
# 9329     True
# 9330    False
# 9331    False
# Name: mag, Length: 9332, dtype: bool

# %%
df[df.mag >= 7.0]
# Out:
#       cdi      code                                             detail   dmin  \
# 837   4.1  1000haa3  https://earthquake.usgs.gov/fdsnws/event/1/que...  1.763
# 5263  8.4  1000h3p4  https://earthquake.usgs.gov/fdsnws/event/1/que...  1.589
#
#       felt   gap                                 ids  mag magType   mmi  ...  \
# 837    3.0  14.0  ,us1000haa3,pt18283003,at00pgehsk,  7.0     mww  7.46  ...
# 5263  18.0  27.0             ,us1000h3p4,us1000h4p4,  7.5     mww  9.12  ...
#
#          sources    status           time  \
# 837   ,us,pt,at,  reviewed  1539204500290
# 5263     ,us,us,  reviewed  1538128963480
#
#                                            title  tsunami        type  \
# 837   M 7.0 - 117km E of Kimbe, Papua New Guinea        1  earthquake
# 5263           M 7.5 - 78km N of Palu, Indonesia        1  earthquake
#
#                                                   types     tz        updated  \
# ...

# %%
df.loc[
    df.mag >= 7.0,
    ['alert', 'mag', 'magType', 'title', 'tsunami', 'type']
]
# Out:
#       alert  mag magType                                       title  tsunami  \
# 837   green  7.0     mww  M 7.0 - 117km E of Kimbe, Papua New Guinea        1
# 5263    red  7.5     mww           M 7.5 - 78km N of Palu, Indonesia        1
#
#             type
# 837   earthquake
# 5263  earthquake

# %%
df.loc[
    (df.place.str.contains('Alaska')) & (df.alert.notnull()),
    ['alert', 'mag', 'magType', 'title', 'tsunami', 'type']
]
# Out:
#       alert  mag magType                                        title  \
# 1015  green  5.0      ml     M 5.0 - 61km SSW of Chignik Lake, Alaska
# 1273  green  4.0      ml          M 4.0 - 71km SW of Kaktovik, Alaska
# 1795  green  4.0      ml           M 4.0 - 60km WNW of Valdez, Alaska
# 2752  green  4.0      ml         M 4.0 - 67km SSW of Kaktovik, Alaska
# 3260  green  3.9      ml       M 3.9 - 44km N of North Nenana, Alaska
# 4101  green  4.2      ml  M 4.2 - 131km NNW of Arctic Village, Alaska
# 6897  green  3.8      ml         M 3.8 - 80km SSW of Kaktovik, Alaska
# 8524  green  3.8      ml         M 3.8 - 69km SSW of Kaktovik, Alaska
# 9133  green  5.1      ml         M 5.1 - 64km SSW of Kaktovik, Alaska
#
#       tsunami        type
# 1015        1  earthquake
# 1273        1  earthquake
# 1795        1  earthquake
# 2752        1  earthquake
# 3260        0  earthquake
# 4101        0  earthquake
# 6897        0  earthquake
# 8524        0  earthquake
# ...

# %%
df.filter(items=['mag', 'magType']).head()
# Out:
#     mag magType
# 0  1.35      ml
# 1  1.29      ml
# 2  3.42      ml
# 3  0.44      ml
# 4  2.16      md

# %%
df.set_index('place').filter(like='Japan', axis=0).filter(items=['mag', 'magType', 'title']).head()
# Out:
#                              mag magType                                title
# place
# 160km NNW of Nago, Japan     4.6      mb     M 4.6 - 160km NNW of Nago, Japan
# 7km ESE of Asahi, Japan      5.2     mww      M 5.2 - 7km ESE of Asahi, Japan
# 14km E of Tomakomai, Japan   4.5     mwr   M 4.5 - 14km E of Tomakomai, Japan
# 139km WSW of Naze, Japan     4.7      mb     M 4.7 - 139km WSW of Naze, Japan
# 53km ESE of Kamaishi, Japan  4.6      mb  M 4.6 - 53km ESE of Kamaishi, Japan

# %%
df.columns
# Out:
# Index(['alert', 'cdi', 'code', 'detail', 'dmin', 'felt', 'gap', 'ids', 'mag',
#        'magType', 'mmi', 'net', 'nst', 'place', 'rms', 'sig', 'sources',
#        'status', 'time', 'title', 'tsunami', 'type', 'types', 'tz', 'updated',
#        'url'],
#       dtype='object')

# %%
# task4
df.loc[3:10, ['mag', 'magType', 'type']]
# Out:
#      mag magType        type
# 3   0.44      ml  earthquake
# 4   2.16      md  earthquake
# 5   2.61      md  earthquake
# 6   1.70      ml  earthquake
# 7   1.13      md  earthquake
# 8   0.92      md  earthquake
# 9   4.70      mb  earthquake
# 10  0.50      ml  earthquake

# %%
df.iloc[3:10,[8,9,21]]
# Out:
#     mag magType        type
# 3  0.44      ml  earthquake
# 4  2.16      md  earthquake
# 5  2.61      md  earthquake
# 6  1.70      ml  earthquake
# 7  1.13      md  earthquake
# 8  0.92      md  earthquake
# 9  4.70      mb  earthquake

# %%
ari = df[df['place'].str.contains('Arizona')]
ari.loc[:,['place','mag','magType','type']]
# Out:
#                                   place   mag magType        type
# 1062  7km SSW of Colorado City, Arizona  1.23      ml  earthquake
# 3965  7km WSW of Colorado City, Arizona  0.94      md  earthquake

# %% [markdown]
# # adding_and_removing_data

# %%
import pandas as pd

df = pd.read_csv(
    'data/earthquakes.csv',
    usecols=['time', 'title', 'place', 'magType', 'mag', 'alert', 'tsunami']
)

# %%
df
# Out:
#      alert   mag magType                             place           time  \
# 0      NaN  1.35      ml             9km NE of Aguanga, CA  1539475168010
# 1      NaN  1.29      ml             9km NE of Aguanga, CA  1539475129610
# 2      NaN  3.42      ml             8km NE of Aguanga, CA  1539475062610
# 3      NaN  0.44      ml             9km NE of Aguanga, CA  1539474978070
# 4      NaN  2.16      md             10km NW of Avenal, CA  1539474716050
# ...    ...   ...     ...                               ...            ...
# 9327   NaN  0.62      md      9km ENE of Mammoth Lakes, CA  1537230228060
# 9328   NaN  1.00      ml               3km W of Julian, CA  1537230135130
# 9329   NaN  2.40      md  35km NNE of Hatillo, Puerto Rico  1537229908180
# 9330   NaN  1.10      ml             9km NE of Aguanga, CA  1537229545350
# 9331   NaN  0.66      ml             9km NE of Aguanga, CA  1537228864470
#
#                                          title  tsunami
# ...

# %%
# task5
df2=df.pop('alert')

# %%
df2.head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: alert, dtype: object

# %%
df.columns
# Out:
# Index(['mag', 'magType', 'place', 'time', 'title', 'tsunami'], dtype='object')

# %%
mag = df.pop('mag')
magType = df.pop('magType')

# %%
df.columns
# Out:
# Index(['place', 'time', 'title', 'tsunami'], dtype='object')

# %%
pd.concat(
    [df.mag, df.magType], join='inner',axis=1)
# Out:
#        mag magType
# 0     1.35      ml
# 1     1.29      ml
# 2     3.42      ml
# 3     0.44      ml
# 4     2.16      md
# ...    ...     ...
# 9327  0.62      md
# 9328  1.00      ml
# 9329  2.40      md
# 9330  1.10      ml
# 9331  0.66      ml
#
# [9332 rows x 2 columns]
